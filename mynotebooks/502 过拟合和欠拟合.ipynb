# %% [markdown]
# # 502 过拟合和欠拟合

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
np.random.seed(666)
x = np.random.uniform(-3.0, 3.0, size=100)
X = x.reshape(-1, 1)
y = 0.5 * x**2 + x + 2 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x, y)

# %% [markdown]
# ### 使用线性回归

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.score(X, y)
# Out:
# 0.4953707811865009

# %%
y_predict = lin_reg.predict(X)
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict[np.argsort(x)], color='b')

# %%
from sklearn.metrics import mean_squared_error

y_predict = lin_reg.predict(X)
mean_squared_error(y, y_predict)
# Out:
# 3.0750025765636577

# %% [markdown]
# ### 使用多项式回归

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

def PolynomialRegression(degree):
    return Pipeline([
        ("poly", PolynomialFeatures(degree=degree)),
        ("std_scaler", StandardScaler()),
        ("lin_reg", LinearRegression())
    ])

# %%
poly2_reg = PolynomialRegression(degree=2)
poly2_reg.fit(X, y)
# Out:
# Pipeline(memory=None,
#          steps=[('poly',
#                  PolynomialFeatures(degree=2, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('std_scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('lin_reg',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
y2_predict = poly2_reg.predict(X)
mean_squared_error(y, y2_predict)
# Out:
# 1.0987392142417856

# %%
plt.scatter(x,y)
plt.plot(np.sort(x),y2_predict[np.argsort(x)], color='b')

# %%
poly10_reg = PolynomialRegression(degree=10)
poly10_reg.fit(X, y)

y10_predict = poly10_reg.predict(X)
mean_squared_error(y, y10_predict)
# Out:
# 1.0508466763764164

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y10_predict[np.argsort(x)], color='b')

# %%
poly100_reg = PolynomialRegression(degree=100)
poly100_reg.fit(X, y)

y100_predict = poly100_reg.predict(X)
mean_squared_error(y, y100_predict)
# Out:
# 0.687293250556113

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y100_predict[np.argsort(x)], color='b')

# %% [markdown]
# ### 上面的X值是随机的，下面设置等间隔的X值，绘制拟合曲线

# %%
X_plot = np.linspace(-3, 3, 100).reshape(100, 1)
y_plot = poly100_reg.predict(X_plot)

# %%
plt.scatter(x, y)
plt.plot(X_plot[:,0], y_plot, color='b')
plt.axis([-3, 3, 0, 10])
# Out:
# [-3, 3, 0, 10]

# %% [markdown]
# ### train test split的意义

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=666)

# %%
lin_reg.fit(X_train, y_train)
y_predict = lin_reg.predict(X_test)
mean_squared_error(y_test, y_predict)
# Out:
# 2.2199965269396573

# %%
poly2_reg = PolynomialRegression(degree=2)
poly2_reg.fit(X_train, y_train)
y2_predict = poly2_reg.predict(X_test)
mean_squared_error(y_test, y2_predict)
# Out:
# 0.8035641056297901

# %%
poly10_reg = PolynomialRegression(degree=10)
poly10_reg.fit(X_train, y_train)
y10_predict = poly10_reg.predict(X_test)
mean_squared_error(y_test, y10_predict)
# Out:
# 0.9212930722150781

# %%
poly100_reg = PolynomialRegression(degree=100)
poly100_reg.fit(X_train, y_train)
y100_predict = poly100_reg.predict(X_test)
mean_squared_error(y_test, y100_predict)
# Out:
# 14440175276.314638
